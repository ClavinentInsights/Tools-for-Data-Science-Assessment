# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# Exercise 2

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %%
Exercise 3 and 11

# %% [markdown]
# **Maesela Clavinent Aphane**
# <br>Electrical Engineer

# %% [markdown]
# Exercise 10
#
# _I am interested in Data Science because it methodoligically derives insights from data using mathematical computations and analysis. I am particularly interested in deriving business insights to allow for businesses to gain sustainable competitive advantage_

# %% [markdown]
# ### The following code executes and displays output

# %%
print('1+1')
# Out:
# 1+1

# %% [markdown]
# This is the horizontal rule
# ***
# End of horizontal rule

# %% [markdown]
# Exercise 4
# <br>Data Science Languages
# - Python
# - SQl
# - R
# - Java
# - Scala
# - C++
# - Julia
# Exercise 5
# <br>Data Science Libraries
# - TensorFlow
# - SciPy
# - NumPy
# - Pandas
# - Matplotlib
# - Keras
# - Scikit-learn
# - PyTorch
# - Scrapy
# - BeautifulSoup

# %% [markdown]
# | Data Science Tools |
# |----------|
# | Jupyter Notebooks |
# | RStudio |
# | Git/Github |
# | Watson Studio |
# | MySQL |
# | etc. |

# %% [markdown]
# Exercise 7
#
# Examples of arithmetic expressions

# %%
#Exercise 8

x = 1 + 1
print("x =",x)
y = 2 * 2
print("y =",y)
# Out:
# x = 2
# y = 4

# %%
#Exercise 9

_minutes = 120
_hours = _minutes/60
print( "For minute =",_minutes, "Then hours =",_hours)
# Out:
# For minute = 120 Then hours = 2.0

# %% [markdown]
# Exercise 12

# %% [markdown]
# ![IMG-0821.jpg](attachment:ddb8b708-a719-4f66-a5e0-3789affb57ee.jpg)
